# %% [markdown]
# # Data Understanding
#
# Dataset yang digunakan adalah **Iris Dataset** yang berisi informasi mengenai karakteristik bunga iris.
# Dataset ini memiliki **5 fitur utama** selain Id, yaitu panjang dan lebar sepal, panjang dan lebar petal, serta jenis spesies bunga.
#
# ## Struktur Data
#
# | Kolom           | Tipe Data   | Deskripsi                                                                 |
# |-----------------|-------------|----------------------------------------------------------------------------|
# | Id              | Integer     | Nomor urut atau identitas unik untuk setiap data bunga.                    |
# | SepalLengthCm   | Float       | Panjang sepal (kelopak bunga) dalam satuan sentimeter.                     |
# | SepalWidthCm    | Float       | Lebar sepal (kelopak bunga) dalam satuan sentimeter.                       |
# | PetalLengthCm   | Float       | Panjang petal (mahkota bunga) dalam satuan sentimeter.                     |
# | PetalWidthCm    | Float       | Lebar petal (mahkota bunga) dalam satuan sentimeter.                       |
# | Species         | Kategori    | Jenis bunga iris (Iris-setosa, Iris-versicolor, Iris-virginica).            |
#
# ---
#
# ## Ringkasan Statistik
#
# | Feature        | Min | Max | Mean | Std Dev |
# |----------------|-----|-----|------|---------|
# | SepalLengthCm  | 4.3 | 7.9 | 5.84 | 0.83    |
# | SepalWidthCm   | 2.0 | 4.4 | 3.05 | 0.43    |
# | PetalLengthCm  | 1.0 | 6.9 | 3.76 | 1.76    |
# | PetalWidthCm   | 0.1 | 2.5 | 1.20 | 0.76    |
#
# ---
#
# ## Kesimpulan
#
# Berdasarkan analisis awal terhadap dataset Iris, dapat ditarik beberapa poin penting:
#
# 1. Dataset terdiri dari 150 sampel dengan distribusi yang seimbang, masing-masing spesies
#    (Iris-setosa, Iris-versicolor, Iris-virginica) memiliki 50 data. Hal ini memastikan
#    tidak adanya masalah ketidakseimbangan kelas (class imbalance).
#
# 2. Fitur numerik yang digunakan adalah Sepal Length, Sepal Width, Petal Length, dan Petal Width.
#    Setiap fitur memiliki rentang nilai (min–max), rata-rata, dan standar deviasi yang berbeda.
#
# 3. Fitur Petal (panjang dan lebar) menunjukkan variasi yang lebih besar dibandingkan dengan fitur Sepal.
#    Hal ini terlihat dari nilai standar deviasi yang lebih tinggi pada Petal Length dan Petal Width.
#
# 4. Fitur Sepal cenderung lebih stabil (rentang data lebih sempit dan standar deviasi lebih kecil).
#    Sebaliknya, fitur Petal lebih bervariasi sehingga berpotensi menjadi indikator utama dalam klasifikasi spesies.
#
# 5. Secara keseluruhan, dataset ini sangat ideal untuk digunakan sebagai studi kasus dalam analisis data
#    maupun pemodelan machine learning, karena memiliki data yang bersih, seimbang, dan jelas perbedaan antar fiturnya.

# %% [markdown]
# ## Deskripsi Diagram Petal Width (cm)
# ![petalwidth.png](data:image/png;base64,...)
#
# Diagram batang di atas menunjukkan distribusi **lebar kelopak bunga (Petal Width Cm)** pada dataset Iris dengan tiga ukuran statistik utama: **minimum, rata-rata, dan maksimum**.
#
# - **Minimum (Min): 0.10 cm**
#   Menunjukkan ada bunga dengan lebar kelopak sangat kecil, mendekati nol.
#
# - **Rata-rata (Average): 1.20 cm**
#   Menggambarkan ukuran lebar kelopak rata-rata dari seluruh bunga dalam dataset.
#
# - **Maksimum (Max): 2.50 cm**
#   Menunjukkan bunga dengan lebar kelopak terbesar mencapai 2.5 cm.
#
# Secara keseluruhan, terlihat adanya rentang (range) yang cukup besar antara nilai minimum dan maksimum. Hal ini menandakan variasi ukuran lebar kelopak antar spesies cukup tinggi. Dengan demikian, atribut **Petal Width** dapat menjadi salah satu indikator penting dalam membedakan spesies bunga iris.

# %% [markdown]
# ## Deskripsi Diagram Petal Length (cm)
# ![image.png](data:image/png;base64,...)
#
# Diagram batang di atas menunjukkan distribusi **panjang kelopak bunga (Petal Length Cm)** pada dataset Iris dengan tiga ukuran statistik utama: **minimum, rata-rata, dan maksimum**.
#
# - **Minimum (Min): 1.00 cm**
#   Menunjukkan bunga dengan panjang kelopak terkecil sebesar 1.0 cm.
#
# - **Rata-rata (Average): 3.76 cm**
#   Menggambarkan ukuran panjang kelopak rata-rata dari seluruh bunga dalam dataset.
#
# - **Maksimum (Max): 6.90 cm**
#   Menunjukkan bunga dengan panjang kelopak terbesar mencapai 6.9 cm.
#
# Secara keseluruhan, terlihat adanya perbedaan yang cukup besar antara nilai minimum dan maksimum. Hal ini menandakan bahwa **Petal Length** memiliki variasi yang sangat signifikan antar spesies bunga iris. Oleh karena itu, atribut ini menjadi salah satu indikator yang sangat penting dalam membedakan spesies pada dataset iris.

# %% [markdown]
# ## Deskripsi Diagram Sepal Length (cm)
# ![image.png](data:image/png;base64,...)
#
# Diagram batang di atas menggambarkan distribusi **panjang sepal (Sepal Length Cm)** pada dataset Iris dengan tiga ukuran statistik utama: **minimum, rata-rata, dan maksimum**.
#
# - **Minimum (Min): 4.30 cm**
#   Menunjukkan ada bunga dengan panjang sepal terkecil sebesar 4.3 cm.
#
# - **Rata-rata (Average): 5.84 cm**
#   Menggambarkan ukuran panjang sepal rata-rata dari seluruh bunga dalam dataset.
#
# - **Maksimum (Max): 7.90 cm**
#   Menunjukkan bunga dengan panjang sepal terbesar mencapai 7.9 cm.
#
# Secara keseluruhan, rentang antara nilai minimum dan maksimum cukup lebar. Hal ini menunjukkan adanya variasi panjang sepal yang signifikan antar spesies bunga iris. Dengan demikian, atribut **Sepal Length** dapat dijadikan salah satu faktor penting dalam membedakan spesies pada dataset ini.

# %% [markdown]
# ## Deskripsi Diagram Sepal Width (cm)
# ![sepalwidth.png](data:image/png;base64,...)
#
# Diagram batang di atas menggambarkan distribusi **lebar sepal (Sepal Width Cm)** pada dataset Iris dengan tiga ukuran statistik utama: **minimum, rata-rata, dan maksimum**.
#
# - **Minimum (Min): 2.00 cm**
#   Menunjukkan bunga dengan lebar sepal terkecil sebesar 2.0 cm.
#
# - **Rata-rata (Average): 3.05 cm**
#   Menggambarkan ukuran lebar sepal rata-rata dari seluruh bunga dalam dataset.
#
# - **Maksimum (Max): 4.40 cm**
#   Menunjukkan bunga dengan lebar sepal terbesar mencapai 4.4 cm.
#
# Secara keseluruhan, terdapat selisih cukup lebar antara nilai minimum dan maksimum. Hal ini menunjukkan bahwa variasi ukuran sepal width cukup signifikan antar spesies bunga iris, sehingga atribut ini dapat menjadi salah satu variabel penting dalam proses klasifikasi spesies.

# %% [markdown]
# ## Deskripsi Diagram Distribusi Spesies Iris
# ![class.png](data:image/png;base64,...)
#
# Diagram batang di atas menunjukkan jumlah data untuk setiap spesies bunga **Iris** dalam dataset. Terdapat tiga spesies yang diamati, yaitu **Iris-setosa**, **Iris-versicolor**, dan **Iris-virginica**.
#
# - **Iris-setosa** memiliki jumlah data sebanyak **50 sampel**.
# - **Iris-versicolor** memiliki jumlah data sebanyak **50 sampel**.
# - **Iris-virginica** juga memiliki jumlah data sebanyak **50 sampel**.
#
# Dari hasil ini, dapat disimpulkan bahwa distribusi data antar spesies adalah **seimbang**. Setiap spesies memiliki jumlah sampel yang sama, sehingga dataset Iris ini sangat ideal untuk keperluan analisis statistik maupun pemodelan machine learning, karena tidak terdapat masalah **ketidakseimbangan kelas (class imbalance)**.
